# %%
import panel as pn

pn.extension('tabulator')
from ipywidgets import interact, interact_manual, interactive
import ipywidgets as widgets

pn.extension()
from bokeh.io import output_notebook

pn.extension('plotly')
from polarspike import Rec_UI
from polarspike import Overview

# %matplotlib widget
explorer = Rec_UI.Explorer()
explorer.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='156a1ed8-45f5-49d5-a2f1-283841959c9e'>
#   <div id="e11451c1-e5ff-4a25-92c6-51d53b6b820d" data-root-id="156a1ed8-45f5-49d5-a2f1-283841959c9e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"aad83795-1a38-453a-ac12-626cbcf3b2fc":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"156a1ed8-45f5-49d5-a2f1-283841959c9e"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"7b935eee-c628-4359-bde5-48e98c69e1f9","attributes":{"plot_id":"156a1ed8-45f5-49d5-a2f1-283841959c9e","comm_id":"84a605f7af6247b6befa3835678bc8e9","client_comm_id":"2ba996ce298c46d0bbdcf509384dcd0e"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"aad83795-1a38-453a-ac12-626cbcf3b2fc","roots":{"156a1ed8-45f5-49d5-a2f1-283841959c9e":"e11451c1-e5ff-4a25-92c6-51d53b6b820d"},"root_ids":["156a1ed8-45f5-49d5-a2f1-283841959c9e"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Row(height=1000, sizing_mode='fixed', width=1000)
#     [0] Column(sizing_mode='fixed', width=300)
#         [0] WidgetBox(max_height=1000, max_width=300, sizing_mode='stretch_width')
#             [0] Markdown(str, margin=(0, 10))
#             [1] Markdown(str)
#             [2] IPyWidget(SelectFilesButton)
#             [3] Markdown(str)
#             [4] IPyWidget(SelectFilesButton)
#             [5] Markdown(str)
#             [6] IPyWidget(SelectFilesButton)
#             [7] TextInput(name='recording name', placeholder='recording name (LC!)', width=200)
#             [8] FloatInput(end=50000.0, name='Recording Frequency', start=0.0, step=1.0, value=10000.0, width=200)
#             [9] Button(button_type='primary', name='Load Recording', width=200)
#             [10] Button(button_type='primary', name='Save to Overview', width=200)
#             [11] Progress(active=False, name='Indeterminate Progress', width=200)
#             [12] StaticText(name='Warnings', value='No warnings')
#     [1] Spacer(width=20)
#     [2] Column(sizing_mode='stretch_width')
#         [0] Tabs(height=800)
#             [0] Row
#                 [0] Column(height=800, sizing_mode='fixed', width=1000)
#                     [0] Column
#                         [0] Row(height=600, sizing_mode='fixed', width=1000)
#                             [0] Bokeh(figure, height=500, sizing_mode='fixed', width=1000)
#                         [1] Row(height=200, sizing_mode='fixed', width=1000)
#                             [0] Tabulator(editors={'stimulus_index': {'type'...}, frozen_columns=['stimulus_name', ...], height=200, name='single stimulus', sizing_mode='fixed', value=Empty DataFrame
# Columns: [..., width=900, widths=150)
#                 [1] Column
#                     [0] Button(button_type='primary', name='Define Stimuli', width=150)
#                     [1] Button(button_type='primary', name='Match stimulus spikes', width=150)
#             [1] Tabs(sizing_mode='stretch_width')
#                 [0] Column(sizing_mode='stretch_width')
#                     [0] IPyWidget(Output)
#                 [1] Column(sizing_mode='stretch_width')
#                     [0] IPyWidget(Output)
#                 [2] Column(sizing_mode='stretch_width')
#                     [0] IPyWidget(Output)
#                 [3] Column(sizing_mode='stretch_width')
#                     [0] IPyWidget(Output)
#             [2] Row
#                 [0] Column
#                     [0] Select()
#                     [1] Select(options=['FFF_4_UV', 'FFF_4', ...], value='FFF_4_UV')
#                     [2] IPyWidget(HBox)
#                 [1] Column
#                     [0] Row(width=1000)
#                         [0] Tabulator(height=200, name='single stimulus', sizing_mode='fixed', value=Empty DataFrame
# Columns: [..., width=900, widths=150)
#                         [1] Button(name='Calculate QI', width=150)
#                     [1] Row(width=1000)
#                         [0] Plotly(Figure)
