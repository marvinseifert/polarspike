# %%
from polarspike import Overview
from polarspike import stimulus_spikes
from polarspike import stimulus_trace, colour_template, spiketrain_plots
from pathlib import Path
from polarspike import Rec_UI
import numpy as np
import panel as pn
import ipywidgets as widgets
from bokeh.plotting import show, curdoc

curdoc().theme = 'dark_minimal'

pn.extension('tabulator')
pn.extension('plotly')
pn.extension('ipywidgets')
import sys
sys.modules["Overview"] = Overview

# %matplotlib widget
from importlib import reload
from polarspike import grid
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# ...

# %%
reload(Rec_UI)
REC = Rec_UI.Recording_explorer(r"D:\combined_analysis")

# %%
REC.serve()
# Out:
# string</br>
# Row(design=<class 'panel.theme.bootst..., sizing_mode='stretch_width')
#     [0] Column(design=<class 'panel.theme.bootst..., height=300, sizing_mode='fixed', width=300)
#         [0] WidgetBox(css_classes=['panel-widget-box', ...], design=<class 'panel.theme.bootst..., height=1000, scroll=True, sizing_mode='fixed', width=310)
#             [0] Markdown(str, design=<class 'panel.theme.bootst...)
#             [1] IPyWidget(SelectFilesButton, design=<class 'panel.theme.bootst...)
#             [2] Markdown(str, design=<class 'panel.theme.bootst...)
#             [3] IPyWidget(SelectFilesButton, design=<class 'panel.theme.bootst...)
#             [4] Row(design=<class 'panel.theme.bootst...)
#                 [0] TextInput(design=<class 'panel.theme.bootst..., placeholder='overview', width=120)
#                 [1] Button(design=<class 'panel.theme.bootst..., name='💾 Save Analysis')
# ...

# %%
REC.grid_row.objects[0][1].value["nr_of_spikes"].dtype
# Out:
# dtype('uint32')

# %%
REC.run_quality_tests(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 REC.run_quality_tests(1)
#
# File ~\github_packages\polarspike\Rec_UI.py:1051, in Recording_explorer.run_quality_tests(self, event)
#    1049 insert_df.update(quality_df)
#    1050 insert_df = insert_df.reset_index(drop=False)
# -> 1051 self.return_values_to_df(insert_df, ["qi"], ["float"])
#
# File ~\github_packages\polarspike\Rec_UI.py:1002, in Recording_explorer.return_values_to_df(self, df, new_columns, column_dtypes)
#     998     self.recordings_object.dataframes[df_name][
#     999         column
#    1000     ] = self.recordings_object.dataframes[df_name][column].astype(int)
#    1001 elif dtype == "float":
# -> 1002     self.recordings_object.dataframes[df_name][column] = numeric_fill
#    1003     self.recordings_object.dataframes[df_name][
#    1004         column
# ...

# %%
pn.extension('floatpanel')
warning_text = "This will overwrite the current analysis. Are you sure?"
w1 = pn.widgets.StaticText(value=warning_text)
w2 = pn.widgets.Button(name="Yes", button_type="primary")
w3 = pn.widgets.Button(name="No", button_type="danger")

floatpanel = pn.layout.FloatPanel(
    w1, w2, w3, name="Warning", contained=False, position="center"
)
floatpanel.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# ...

# %%
spikes = REC.recordings_object.get_spikes_df(
                    cell_df="cell_selection", pandas=False
                )

# %%
spikes["repeat"].max()
# Out:
# 9
