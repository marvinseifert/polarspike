# %%
import sys
sys.path.extend(['/home/mawa/PycharmProjects/polarspike', '/home/mawa/PycharmProjects/polarspike/core'])
from polarspike import Overview
from polarspike import Rec_UI
import panel as pn
from bokeh.plotting import curdoc

curdoc().theme = 'dark_minimal'

pn.extension('tabulator')
pn.extension('plotly')
pn.extension('ipywidgets')
import sys

sys.modules["Overview"] = Overview

# %matplotlib widget
from importlib import reload
import panel as pn

pn.extension(debug=True)
# Out:
# ...
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# ...

# %%
reload(Rec_UI)
REC = Rec_UI.Recording_explorer(r"~/data_disk/combined_analysis")

# %%
REC.serve()
# Out:
# Row(sizing_mode='stretch_width')
#     [0] Column(height=300, sizing_mode='fixed', width=300)
#         [0] WidgetBox(css_classes=['panel-widget-box', ...], height=1000, scroll=True, sizing_mode='fixed', width=310)
#             [0] Markdown(str)
#             [1] IPyWidget(SelectFilesButton)
#             [2] Markdown(str)
#             [3] IPyWidget(SelectFilesButton)
#             [4] Row
#                 [0] TextInput(placeholder='overview', width=120)
#                 [1] Button(name='💾 Save Analysis')
#             [5] Column(sizing_mode='stretch_width')
#                 [0] MenuButton(button_type='primary', items=['raster_plot', ...], name='Actions', width=200)
#             [6] Column(height=800, sizing_mode='fixed', width=310)
#                 [0] JSON(list)
#     [1] Spacer(width=20)
#     [2] Column(height=1000, sizing_mode='fixed', width=1000)
#         [0] Tabs(height=1000, sizing_mode='fixed', width=1500)
#             [0] Column(sizing_mode='stretch_width')
# ...

# %%
recording = Overview.Recording.load(r"B:\Marvin\Chicken_02_09_2024\Phase_00\overview")

# %%
recording.parquet_path = r"B:\Marvin\Chicken_02_09_2024\Phase_00\alldata.parquet"

# %%
recording.save(recording.load_path)
